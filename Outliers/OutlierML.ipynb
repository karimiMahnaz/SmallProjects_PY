# %%
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples= 10, n_features=1, noise=5)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X, y)
plt.xlabel('feature')
plt.ylabel('target')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y, alpha=.7)
plt.plot(X, y_pred)
plt.xlabel('feature')
plt.ylabel('target')
plt.show()

# %%
import numpy as np

# %%
x_new = np.concatenate((X, [[-.9],[0]]))
y_new = np.concatenate((y, [60, 55]))

# %%
plt.scatter(x_new, y_new)
plt.xlabel('Feature')
plt.ylabel('Target')
plt.show()

# %%
model = LinearRegression()
model.fit(x_new, y_new)
# Out:
# LinearRegression()

# %%
y_pred_new = model.predict(x_new)

# %%
plt.scatter(x_new, y_new, alpha=.5)
plt.plot(X, y_pred)
plt.plot(x_new, y_pred_new)

plt.xlabel('Feature')
plt.ylabel('Target')

plt.show()
