# %%
documents = ['Keras is a deep learning API written in Python',
             'The core data structures of Keras are layers and models',
             'What you just saw is the most elementary way to use Keras',
             'If you need to, you can further configure your optimizer',
             'Computing the gradient of arbitrary differentiable expressions'
                ]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(documents)

# %%
input_dim = len(tokenizer.word_index) + 1

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('keras', 3),
#              ('is', 2),
#              ('a', 1),
#              ('deep', 1),
#              ('learning', 1),
#              ('api', 1),
#              ('written', 1),
#              ('in', 1),
#              ('python', 1),
#              ('the', 3),
#              ('core', 1),
#              ('data', 1),
#              ('structures', 1),
#              ('of', 2),
#              ('are', 1),
#              ('layers', 1),
#              ('and', 1),
#              ('models', 1),
#              ('what', 1),
#              ('you', 3),
#              ('just', 1),
#              ('saw', 1),
#              ('most', 1),
#              ('elementary', 1),
#              ('way', 1),
#              ('to', 2),
#              ('use', 1),
#              ('if', 1),
#              ('need', 1),
#              ('can', 1),
#              ('further', 1),
#              ('configure', 1),
#              ('your', 1),
#              ('optimizer', 1),
# ...

# %%
encode = tokenizer.texts_to_sequences(documents)

# %%
list_len = [] 
for seq in encode:
    list_len.append(len(seq))

# %%
max_len = max(list_len)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
padded_encode = pad_sequences(encode,maxlen=max_len,padding='post')

# %%
padded_encode
# Out:
# array([[ 1,  4,  7,  8,  9, 10, 11, 12, 13,  0,  0,  0],
#        [ 2, 14, 15, 16,  5,  1, 17, 18, 19, 20,  0,  0],
#        [21,  3, 22, 23,  4,  2, 24, 25, 26,  6, 27,  1],
#        [28,  3, 29,  6,  3, 30, 31, 32, 33, 34,  0,  0],
#        [35,  2, 36,  5, 37, 38, 39,  0,  0,  0,  0,  0]])

# %%
padded_encode.shape
# Out:
# (5, 12)

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(Embedding(input_dim=input_dim,output_dim=50))

# %%
pred = model.predict(padded_encode)
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %%
pred.shape
# Out:
# (5, 12, 50)

# %%
pred[0][0]
# Out:
# array([-0.01062628, -0.00579154, -0.02418983, -0.02771338,  0.04748731,
#        -0.04631799, -0.01281148, -0.00248212,  0.02535507, -0.04740288,
#         0.00876636, -0.02410665, -0.04416801,  0.01358641,  0.02009393,
#        -0.01659405,  0.03182701, -0.00071103,  0.04621426,  0.04706914,
#         0.01237066,  0.04716331,  0.01079683,  0.0452189 ,  0.03156263,
#        -0.0219951 , -0.01389768, -0.02818825, -0.01905116,  0.0304063 ,
#        -0.04621978,  0.02339182, -0.03316168, -0.00648702,  0.04237558,
#         0.0153545 ,  0.04284226,  0.04099151,  0.03849859, -0.00839031,
#         0.04557801,  0.01011381, -0.01105016,  0.04923493,  0.03552445,
#        -0.03199496, -0.02497664,  0.0405545 , -0.04478576, -0.01459118],
#       dtype=float32)

# %%
pred[1][5]
# Out:
# array([-0.01062628, -0.00579154, -0.02418983, -0.02771338,  0.04748731,
#        -0.04631799, -0.01281148, -0.00248212,  0.02535507, -0.04740288,
#         0.00876636, -0.02410665, -0.04416801,  0.01358641,  0.02009393,
#        -0.01659405,  0.03182701, -0.00071103,  0.04621426,  0.04706914,
#         0.01237066,  0.04716331,  0.01079683,  0.0452189 ,  0.03156263,
#        -0.0219951 , -0.01389768, -0.02818825, -0.01905116,  0.0304063 ,
#        -0.04621978,  0.02339182, -0.03316168, -0.00648702,  0.04237558,
#         0.0153545 ,  0.04284226,  0.04099151,  0.03849859, -0.00839031,
#         0.04557801,  0.01011381, -0.01105016,  0.04923493,  0.03552445,
#        -0.03199496, -0.02497664,  0.0405545 , -0.04478576, -0.01459118],
#       dtype=float32)

# %%
#1D-Conv

# %%
from tensorflow.keras.layers import Conv1D

# %%
model = Sequential()
model.add(Embedding(input_dim=input_dim,output_dim=50))
model.add(Conv1D(filters=8,kernel_size=5))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, None, 50)          2000
#
#  conv1d (Conv1D)             (None, None, 8)           2008
#
# ...
# Total params: 4008 (15.66 KB)
# Trainable params: 4008 (15.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
5 * 12 * 50
# Out:
# 3000

# %%
input_dim * 50
# Out:
# 2000

# %%
(5 * 50 + 1) * 8
# Out:
# 2008
